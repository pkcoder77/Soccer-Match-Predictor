# %%
# connect to my google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# imports
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
CSV_DIR = "/content/drive/My Drive/Summer 2025/ML Soccer/matches.csv"

# %%
matches = pd.read_csv(CSV_DIR)
matches.head()
# Out:
#          Date           Time            Comp        Round  Day Venue Result  \
# 0  2024-08-17  12:30 (11:30)  Premier League  Matchweek 1  Sat  Away      W
# 1  2024-08-25  16:30 (15:30)  Premier League  Matchweek 2  Sun  Home      W
# 2  2024-09-01  16:00 (15:00)  Premier League  Matchweek 3  Sun  Away      W
# 3  2024-09-14  15:00 (14:00)  Premier League  Matchweek 4  Sat  Home      L
# 4  2024-09-21  15:00 (14:00)  Premier League  Matchweek 5  Sat  Home      W
#
#    GF  GA         Opponent  ...  Match Report  Notes  Sh  SoT  Dist FK PK  \
# 0   2   0     Ipswich Town  ...  Match Report    NaN  18    5  14.8  0  0
# 1   2   0        Brentford  ...  Match Report    NaN  19    8  13.6  1  0
# 2   3   0   Manchester Utd  ...  Match Report    NaN  11    3  13.4  0  0
# 3   0   1  Nott'ham Forest  ...  Match Report    NaN  14    5  14.9  0  0
# 4   3   0      Bournemouth  ...  Match Report    NaN  19   12  16.6  0  0
#
#   PKatt Season       Team
# 0     0   2025  Liverpool
# 1     0   2025  Liverpool
# 2     0   2025  Liverpool
# 3     0   2025  Liverpool
# 4     0   2025  Liverpool
#
# [5 rows x 28 columns]

# %%
# Great news because 38 matches * 5 seasosn (2021-2025) * 20 teams = 3800
matches.shape
# Out:
# (3800, 28)

# %% [markdown]
# Create Predictors

# %%
matches['venue_code'] = matches['Venue'].astype('category').cat.codes
matches['opp_code'] = matches['Opponent'].astype('category').cat.codes
matches['hour'] = matches['Time'].str.replace(':.+', '', regex=True).astype('int')
matches['Date'] = pd.to_datetime(matches['Date'])
matches['day_code'] = matches['Date'].dt.dayofweek

# %%
matches['opp_code']
# Out:
# 0       10
# 1        3
# 2       16
# 3       19
# 4        2
#         ..
# 3795    22
# 3796     7
# 3797     8
# 3798    17
# 3799     5
# Name: opp_code, Length: 3800, dtype: int8

# %%
matches['hour']
# Out:
# 0       12
# 1       16
# 2       16
# 3       15
# 4       15
#         ..
# 3795    19
# 3796    15
# 3797    19
# 3798    18
# 3799    16
# Name: hour, Length: 3800, dtype: int64

# %%
matches['day_code']
# Out:
# 0       5
# 1       6
# 2       6
# 3       5
# 4       5
#        ..
# 3795    6
# 3796    5
# 3797    6
# 3798    2
# 3799    6
# Name: day_code, Length: 3800, dtype: int32

# %%
# look to try and account for draws in the future
matches['target'] = (matches['Result'] == 'W').astype('int')
matches['target']
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 3795    0
# 3796    0
# 3797    1
# 3798    0
# 3799    1
# Name: target, Length: 3800, dtype: int64

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

train = matches[matches['Date'] < '2024-06-01']
test = matches[matches['Date'] >= '2024-06-01']

predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
pred = rf.predict(test[predictors])

# %%
acc = accuracy_score(test['target'], pred)
acc
# Out:
# 0.5947368421052631

# %%
combined_df = pd.DataFrame(dict(actual=test['target'], prediction = pred))
pd.crosstab(index=combined_df['actual'], columns=combined_df['prediction'])
# Out:
# prediction    0   1
# actual
# 0           375  98
# 1           210  77

# %%
precision_score(test['target'], pred)
# Out:
# 0.44

# %%
group_matches = matches.groupby('Team')
group = group_matches.get_group('Chelsea')
group
# Out:
#            Date           Time            Comp         Round  Day Venue  \
# 114  2024-08-18  16:30 (15:30)  Premier League   Matchweek 1  Sun  Home
# 115  2024-08-25  14:00 (13:00)  Premier League   Matchweek 2  Sun  Away
# 116  2024-09-01  13:30 (12:30)  Premier League   Matchweek 3  Sun  Home
# 117  2024-09-14  20:00 (19:00)  Premier League   Matchweek 4  Sat  Away
# 118  2024-09-21  12:30 (11:30)  Premier League   Matchweek 5  Sat  Away
# ...         ...            ...             ...           ...  ...   ...
# 3187 2021-05-01  17:30 (16:30)  Premier League  Matchweek 34  Sat  Home
# 3188 2021-05-08  17:30 (16:30)  Premier League  Matchweek 35  Sat  Away
# 3189 2021-05-12  20:15 (19:15)  Premier League  Matchweek 36  Wed  Home
# 3190 2021-05-18  20:15 (19:15)  Premier League  Matchweek 37  Tue  Home
# 3191 2021-05-23  16:00 (15:00)  Premier League  Matchweek 38  Sun  Away
#
#      Result  GF  GA         Opponent  ...  FK  PK  PKatt  Season     Team  \
# 114       L   0   2  Manchester City  ...   0   0      0    2025  Chelsea
# 115       W   6   2           Wolves  ...   1   0      0    2025  Chelsea
# 116       D   1   1   Crystal Palace  ...   1   0      0    2025  Chelsea
# 117       W   1   0      Bournemouth  ...   0   0      0    2025  Chelsea
# 118       W   3   0         West Ham  ...   0   0      0    2025  Chelsea
# ...     ...  ..  ..              ...  ...  ..  ..    ...     ...      ...
# 3187      W   2   0           Fulham  ...   1   0      0    2021  Chelsea
# 3188      W   2   1  Manchester City  ...   1   0      0    2021  Chelsea
# 3189      L   0   1          Arsenal  ...   0   0      0    2021  Chelsea
# 3190      W   2   1   Leicester City  ...   0   1      1    2021  Chelsea
# 3191      L   1   2      Aston Villa  ...   0   0      0    2021  Chelsea
#
#      venue_code opp_code hour day_code  target
# 114           1       15   16        6       0
# 115           0       26   14        6       1
# 116           1        7   13        6       0
# 117           0        2   20        5       1
# 118           0       25   12        5       1
# ...         ...      ...  ...      ...     ...
# 3187          1        9   17        5       1
# 3188          0       15   17        5       1
# 3189          1        0   20        2       0
# 3190          1       12   20        1       1
# 3191          0        1   16        6       0
#
# [190 rows x 33 columns]

# %%
# want to consider form aswell now
def rolling_avgs(group, cols, new_cols):
    group = group.sort_values('Date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
from operator import ne
cols = ['GF', 'GA', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt']
new_cols = [f'{c}_rolling' for c in cols]
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_avgs(group, cols, new_cols)
# Out:
#            Date           Time            Comp         Round  Day Venue  \
# 3157 2020-10-03  12:30 (11:30)  Premier League   Matchweek 4  Sat  Home
# 3158 2020-10-17  15:00 (14:00)  Premier League   Matchweek 5  Sat  Home
# 3159 2020-10-24  17:30 (16:30)  Premier League   Matchweek 6  Sat  Away
# 3160 2020-10-31          15:00  Premier League   Matchweek 7  Sat  Away
# 3161 2020-11-07          17:30  Premier League   Matchweek 8  Sat  Home
# ...         ...            ...             ...           ...  ...   ...
# 147  2025-04-26  12:30 (11:30)  Premier League  Matchweek 34  Sat  Home
# 148  2025-05-04  16:30 (15:30)  Premier League  Matchweek 35  Sun  Home
# 149  2025-05-11  12:00 (11:00)  Premier League  Matchweek 36  Sun  Away
# 150  2025-05-16  20:15 (19:15)  Premier League  Matchweek 37  Fri  Home
# 151  2025-05-25  16:00 (15:00)  Premier League  Matchweek 38  Sun  Away
#
#      Result  GF  GA         Opponent  ...  day_code  target  GF_rolling  \
# 3157      W   4   0   Crystal Palace  ...         5       1    2.000000
# 3158      D   3   3      Southampton  ...         5       0    2.333333
# 3159      D   0   0   Manchester Utd  ...         5       0    3.333333
# 3160      W   3   0          Burnley  ...         5       1    2.333333
# 3161      W   4   1    Sheffield Utd  ...         5       1    2.000000
# ...     ...  ..  ..              ...  ...       ...     ...         ...
# 147       W   1   0          Everton  ...         5       1    1.333333
# 148       W   3   1        Liverpool  ...         6       1    1.666667
# 149       L   0   2    Newcastle Utd  ...         6       0    2.000000
# 150       W   1   0   Manchester Utd  ...         4       1    1.333333
# 151       W   1   0  Nott'ham Forest  ...         6       1    1.333333
#
#       GA_rolling Sh_rolling SoT_rolling Dist_rolling FK_rolling PK_rolling  \
# 3157    2.000000  11.666667    5.333333    21.133333   0.333333   0.333333
# 3158    1.666667  13.666667    5.333333    19.766667   0.333333   0.666667
# 3159    2.000000  16.000000    6.333333    15.966667   0.333333   0.666667
# 3160    1.000000  10.666667    3.333333    16.266667   0.000000   0.666667
# 3161    1.000000  10.333333    5.000000    16.833333   0.333333   0.000000
# ...          ...        ...         ...          ...        ...        ...
# 147     1.000000  22.666667    7.000000    18.166667   0.333333   0.000000
# 148     1.000000  19.000000    7.666667    17.933333   0.333333   0.000000
# 149     0.666667  13.000000    6.333333    16.700000   0.333333   0.333333
# 150     1.000000  12.000000    5.000000    16.633333   0.000000   0.333333
# 151     1.000000  12.333333    3.666667    16.966667   0.333333   0.333333
#
#       PKatt_rolling
# 3157       0.666667
# 3158       1.000000
# 3159       0.666667
# 3160       0.666667
# 3161       0.000000
# ...             ...
# 147        0.000000
# 148        0.000000
# 149        0.333333
# 150        0.333333
# 151        0.333333
#
# [187 rows x 41 columns]

# %%
matches_rolling = matches.groupby('Team').apply(lambda x: rolling_avgs(x, cols, new_cols))
matches_rolling
# Out:
# /tmp/ipython-input-2068685264.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby('Team').apply(lambda x: rolling_avgs(x, cols, new_cols))
#                                    Date           Time            Comp  \
# Team
# Arsenal                 3309 2020-10-04  14:00 (13:00)  Premier League
#                         3310 2020-10-17  17:30 (16:30)  Premier League
#                         3311 2020-10-25          19:15  Premier League
#                         3312 2020-11-01          16:30  Premier League
#                         3313 2020-11-08          19:15  Premier League
# ...                                 ...            ...             ...
# Wolverhampton Wanderers 603  2025-04-26  15:00 (14:00)  Premier League
#                         604  2025-05-02  20:00 (19:00)  Premier League
#                         605  2025-05-10  15:00 (14:00)  Premier League
#                         606  2025-05-20  20:00 (19:00)  Premier League
#                         607  2025-05-25  16:00 (15:00)  Premier League
#
#                                      Round  Day Venue Result  GF  GA  \
# Team
# Arsenal                 3309   Matchweek 4  Sun  Home      W   2   1
#                         3310   Matchweek 5  Sat  Away      L   0   1
#                         3311   Matchweek 6  Sun  Home      L   0   1
#                         3312   Matchweek 7  Sun  Away      W   1   0
#                         3313   Matchweek 8  Sun  Home      L   0   3
# ...                                    ...  ...   ...    ...  ..  ..
# Wolverhampton Wanderers 603   Matchweek 34  Sat  Home      W   3   0
#                         604   Matchweek 35  Fri  Away      L   0   1
#                         605   Matchweek 36  Sat  Home      L   0   2
#                         606   Matchweek 37  Tue  Away      L   2   4
#                         607   Matchweek 38  Sun  Home      D   1   1
#
#                                      Opponent  ...  day_code  target  \
# Team                                           ...
# Arsenal                 3309    Sheffield Utd  ...         6       1
#                         3310  Manchester City  ...         5       0
#                         3311   Leicester City  ...         6       0
#                         3312   Manchester Utd  ...         6       1
#                         3313      Aston Villa  ...         6       0
# ...                                       ...  ...       ...     ...
# Wolverhampton Wanderers 603    Leicester City  ...         5       1
#                         604   Manchester City  ...         4       0
#                         605          Brighton  ...         5       0
#                         606    Crystal Palace  ...         1       0
#                         607         Brentford  ...         6       0
#
#                               GF_rolling  GA_rolling Sh_rolling SoT_rolling  \
# Team
# Arsenal                 3309    2.000000    1.333333   8.000000    3.666667
#                         3310    1.666667    1.666667   5.666667    3.666667
#                         3311    1.000000    1.666667   7.000000    3.666667
#                         3312    0.666667    1.000000   9.666667    4.000000
#                         3313    0.333333    0.666667   9.666667    2.666667
# ...                                  ...         ...        ...         ...
# Wolverhampton Wanderers 603     2.333333    1.000000  13.000000    4.333333
#                         604     2.666667    0.666667  12.333333    4.000000
#                         605     1.333333    0.333333  10.000000    2.333333
#                         606     1.000000    1.000000  12.000000    2.666667
#                         607     0.666667    2.333333   9.333333    2.000000
#
#                              Dist_rolling FK_rolling PK_rolling  PKatt_rolling
# Team
# Arsenal                 3309    14.633333   0.666667   0.000000       0.000000
#                         3310    15.366667   0.000000   0.000000       0.000000
#                         3311    16.566667   0.666667   0.000000       0.000000
#                         3312    16.566667   1.000000   0.000000       0.000000
#                         3313    19.333333   1.000000   0.333333       0.333333
# ...                                   ...        ...        ...            ...
# Wolverhampton Wanderers 603     16.433333   0.666667   0.000000       0.000000
#                         604     18.633333   1.000000   0.000000       0.000000
#                         605     18.900000   0.666667   0.000000       0.000000
#                         606     17.200000   0.333333   0.000000       0.000000
#                         607     15.633333   0.000000   0.000000       0.000000
#
# [3716 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('Team')
matches_rolling
# Out:
#            Date           Time            Comp         Round  Day Venue  \
# 3309 2020-10-04  14:00 (13:00)  Premier League   Matchweek 4  Sun  Home
# 3310 2020-10-17  17:30 (16:30)  Premier League   Matchweek 5  Sat  Away
# 3311 2020-10-25          19:15  Premier League   Matchweek 6  Sun  Home
# 3312 2020-11-01          16:30  Premier League   Matchweek 7  Sun  Away
# 3313 2020-11-08          19:15  Premier League   Matchweek 8  Sun  Home
# ...         ...            ...             ...           ...  ...   ...
# 603  2025-04-26  15:00 (14:00)  Premier League  Matchweek 34  Sat  Home
# 604  2025-05-02  20:00 (19:00)  Premier League  Matchweek 35  Fri  Away
# 605  2025-05-10  15:00 (14:00)  Premier League  Matchweek 36  Sat  Home
# 606  2025-05-20  20:00 (19:00)  Premier League  Matchweek 37  Tue  Away
# 607  2025-05-25  16:00 (15:00)  Premier League  Matchweek 38  Sun  Home
#
#      Result  GF  GA         Opponent  ...  day_code  target  GF_rolling  \
# 3309      W   2   1    Sheffield Utd  ...         6       1    2.000000
# 3310      L   0   1  Manchester City  ...         5       0    1.666667
# 3311      L   0   1   Leicester City  ...         6       0    1.000000
# 3312      W   1   0   Manchester Utd  ...         6       1    0.666667
# 3313      L   0   3      Aston Villa  ...         6       0    0.333333
# ...     ...  ..  ..              ...  ...       ...     ...         ...
# 603       W   3   0   Leicester City  ...         5       1    2.333333
# 604       L   0   1  Manchester City  ...         4       0    2.666667
# 605       L   0   2         Brighton  ...         5       0    1.333333
# 606       L   2   4   Crystal Palace  ...         1       0    1.000000
# 607       D   1   1        Brentford  ...         6       0    0.666667
#
#       GA_rolling Sh_rolling SoT_rolling Dist_rolling FK_rolling PK_rolling  \
# 3309    1.333333   8.000000    3.666667    14.633333   0.666667   0.000000
# 3310    1.666667   5.666667    3.666667    15.366667   0.000000   0.000000
# 3311    1.666667   7.000000    3.666667    16.566667   0.666667   0.000000
# 3312    1.000000   9.666667    4.000000    16.566667   1.000000   0.000000
# 3313    0.666667   9.666667    2.666667    19.333333   1.000000   0.333333
# ...          ...        ...         ...          ...        ...        ...
# 603     1.000000  13.000000    4.333333    16.433333   0.666667   0.000000
# 604     0.666667  12.333333    4.000000    18.633333   1.000000   0.000000
# 605     0.333333  10.000000    2.333333    18.900000   0.666667   0.000000
# 606     1.000000  12.000000    2.666667    17.200000   0.333333   0.000000
# 607     2.333333   9.333333    2.000000    15.633333   0.000000   0.000000
#
#       PKatt_rolling
# 3309       0.000000
# 3310       0.000000
# 3311       0.000000
# 3312       0.000000
# 3313       0.333333
# ...             ...
# 603        0.000000
# 604        0.000000
# 605        0.000000
# 606        0.000000
# 607        0.000000
#
# [3716 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            Date           Time            Comp         Round  Day Venue  \
# 0    2020-10-04  14:00 (13:00)  Premier League   Matchweek 4  Sun  Home
# 1    2020-10-17  17:30 (16:30)  Premier League   Matchweek 5  Sat  Away
# 2    2020-10-25          19:15  Premier League   Matchweek 6  Sun  Home
# 3    2020-11-01          16:30  Premier League   Matchweek 7  Sun  Away
# 4    2020-11-08          19:15  Premier League   Matchweek 8  Sun  Home
# ...         ...            ...             ...           ...  ...   ...
# 3711 2025-04-26  15:00 (14:00)  Premier League  Matchweek 34  Sat  Home
# 3712 2025-05-02  20:00 (19:00)  Premier League  Matchweek 35  Fri  Away
# 3713 2025-05-10  15:00 (14:00)  Premier League  Matchweek 36  Sat  Home
# 3714 2025-05-20  20:00 (19:00)  Premier League  Matchweek 37  Tue  Away
# 3715 2025-05-25  16:00 (15:00)  Premier League  Matchweek 38  Sun  Home
#
#      Result  GF  GA         Opponent  ...  day_code  target  GF_rolling  \
# 0         W   2   1    Sheffield Utd  ...         6       1    2.000000
# 1         L   0   1  Manchester City  ...         5       0    1.666667
# 2         L   0   1   Leicester City  ...         6       0    1.000000
# 3         W   1   0   Manchester Utd  ...         6       1    0.666667
# 4         L   0   3      Aston Villa  ...         6       0    0.333333
# ...     ...  ..  ..              ...  ...       ...     ...         ...
# 3711      W   3   0   Leicester City  ...         5       1    2.333333
# 3712      L   0   1  Manchester City  ...         4       0    2.666667
# 3713      L   0   2         Brighton  ...         5       0    1.333333
# 3714      L   2   4   Crystal Palace  ...         1       0    1.000000
# 3715      D   1   1        Brentford  ...         6       0    0.666667
#
#       GA_rolling Sh_rolling SoT_rolling Dist_rolling FK_rolling PK_rolling  \
# 0       1.333333   8.000000    3.666667    14.633333   0.666667   0.000000
# 1       1.666667   5.666667    3.666667    15.366667   0.000000   0.000000
# 2       1.666667   7.000000    3.666667    16.566667   0.666667   0.000000
# 3       1.000000   9.666667    4.000000    16.566667   1.000000   0.000000
# 4       0.666667   9.666667    2.666667    19.333333   1.000000   0.333333
# ...          ...        ...         ...          ...        ...        ...
# 3711    1.000000  13.000000    4.333333    16.433333   0.666667   0.000000
# 3712    0.666667  12.333333    4.000000    18.633333   1.000000   0.000000
# 3713    0.333333  10.000000    2.333333    18.900000   0.666667   0.000000
# 3714    1.000000  12.000000    2.666667    17.200000   0.333333   0.000000
# 3715    2.333333   9.333333    2.000000    15.633333   0.000000   0.000000
#
#       PKatt_rolling
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.333333
# ...             ...
# 3711       0.000000
# 3712       0.000000
# 3713       0.000000
# 3714       0.000000
# 3715       0.000000
#
# [3716 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data['Date'] < '2024-06-01']
    test = data[data['Date'] >= '2024-06-01']
    rf.fit(train[predictors], train['target'])
    pred = rf.predict(test[predictors])
    combined_df = pd.DataFrame(dict(actual=test['target'], prediction = pred), index=test.index)
    precision = precision_score(test['target'], pred)
    return combined_df, precision

# %%
combined_df, precision = make_predictions(matches_rolling, predictors + new_cols)
precision
# Out:
# 0.470873786407767

# %%
combined_df = combined_df.merge(matches_rolling[['Date', 'Team', 'Opponent', 'Result']], left_index=True, right_index=True)
combined_df
# Out:
#       actual  prediction       Date                     Team         Opponent  \
# 149        1           1 2024-08-17                  Arsenal           Wolves
# 150        1           0 2024-08-24                  Arsenal      Aston Villa
# 151        0           1 2024-08-31                  Arsenal         Brighton
# 152        1           1 2024-09-15                  Arsenal        Tottenham
# 153        0           0 2024-09-22                  Arsenal  Manchester City
# ...      ...         ...        ...                      ...              ...
# 3711       1           0 2025-04-26  Wolverhampton Wanderers   Leicester City
# 3712       0           0 2025-05-02  Wolverhampton Wanderers  Manchester City
# 3713       0           0 2025-05-10  Wolverhampton Wanderers         Brighton
# 3714       0           0 2025-05-20  Wolverhampton Wanderers   Crystal Palace
# 3715       0           0 2025-05-25  Wolverhampton Wanderers        Brentford
#
#      Result
# 149       W
# 150       W
# 151       D
# 152       W
# 153       D
# ...     ...
# 3711      W
# 3712      L
# 3713      L
# 3714      L
# 3715      D
#
# [757 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton",
              "Manchester United": "Manchester Utd",
              "Newcastle United": "Newcastle Utd",
              "Tottenham Hotspur": "Tottenham",
              "West Ham United": "West Ham",
              "Wolverhampton Wanderers":
              "Wolves"}
mapping = MissingDict(**map_values)

# %%
mapping['West Ham United']
# Out:
# 'West Ham'

# %%
combined_df['new team'] = combined_df['Team'].map(mapping)
combined_df
# Out:
#       actual  prediction       Date                     Team         Opponent  \
# 149        1           1 2024-08-17                  Arsenal           Wolves
# 150        1           0 2024-08-24                  Arsenal      Aston Villa
# 151        0           1 2024-08-31                  Arsenal         Brighton
# 152        1           1 2024-09-15                  Arsenal        Tottenham
# 153        0           0 2024-09-22                  Arsenal  Manchester City
# ...      ...         ...        ...                      ...              ...
# 3711       1           0 2025-04-26  Wolverhampton Wanderers   Leicester City
# 3712       0           0 2025-05-02  Wolverhampton Wanderers  Manchester City
# 3713       0           0 2025-05-10  Wolverhampton Wanderers         Brighton
# 3714       0           0 2025-05-20  Wolverhampton Wanderers   Crystal Palace
# 3715       0           0 2025-05-25  Wolverhampton Wanderers        Brentford
#
#      Result new team
# 149       W  Arsenal
# 150       W  Arsenal
# 151       D  Arsenal
# 152       W  Arsenal
# 153       D  Arsenal
# ...     ...      ...
# 3711      W   Wolves
# 3712      L   Wolves
# 3713      L   Wolves
# 3714      L   Wolves
# 3715      D   Wolves
#
# [757 rows x 7 columns]

# %%
merged = combined_df.merge(combined_df, left_on=['Date', 'new team'], right_on=['Date', 'Opponent'])
merged
# Out:
#      actual_x  prediction_x       Date                   Team_x  \
# 0           1             1 2024-08-17                  Arsenal
# 1           1             0 2024-08-24                  Arsenal
# 2           0             1 2024-08-31                  Arsenal
# 3           1             1 2024-09-15                  Arsenal
# 4           0             0 2024-09-22                  Arsenal
# ..        ...           ...        ...                      ...
# 711         1             0 2025-04-26  Wolverhampton Wanderers
# 712         0             0 2025-05-02  Wolverhampton Wanderers
# 713         0             0 2025-05-10  Wolverhampton Wanderers
# 714         0             0 2025-05-20  Wolverhampton Wanderers
# 715         0             0 2025-05-25  Wolverhampton Wanderers
#
#           Opponent_x Result_x new team_x  actual_y  prediction_y  \
# 0             Wolves        W    Arsenal         0             0
# 1        Aston Villa        W    Arsenal         0             0
# 2           Brighton        D    Arsenal         0             0
# 3          Tottenham        W    Arsenal         0             0
# 4    Manchester City        D    Arsenal         0             1
# ..               ...      ...        ...       ...           ...
# 711   Leicester City        W     Wolves         0             0
# 712  Manchester City        L     Wolves         1             1
# 713         Brighton        L     Wolves         1             1
# 714   Crystal Palace        L     Wolves         1             0
# 715        Brentford        D     Wolves         0             0
#
#                        Team_y Opponent_y Result_y       new team_y
# 0     Wolverhampton Wanderers    Arsenal        L           Wolves
# 1                 Aston Villa    Arsenal        L      Aston Villa
# 2    Brighton and Hove Albion    Arsenal        D         Brighton
# 3           Tottenham Hotspur    Arsenal        L        Tottenham
# 4             Manchester City    Arsenal        D  Manchester City
# ..                        ...        ...      ...              ...
# 711            Leicester City     Wolves        L   Leicester City
# 712           Manchester City     Wolves        W  Manchester City
# 713  Brighton and Hove Albion     Wolves        W         Brighton
# 714            Crystal Palace     Wolves        W   Crystal Palace
# 715                 Brentford     Wolves        D        Brentford
#
# [716 rows x 13 columns]

# %%
merged[(merged['prediction_x'] == 1) & (merged['prediction_y'] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 0    90
# 1    85
# Name: count, dtype: int64

# %%
cols
# Out:
# ['GF', 'GA', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt']
